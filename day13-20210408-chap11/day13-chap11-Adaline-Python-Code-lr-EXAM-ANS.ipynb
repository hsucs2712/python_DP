# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
import numpy as np
iris = datasets.load_iris()
X = iris['data'][:100, : ]
y = np.where( iris['target'][:100]==0, -1, 1)

# ss = StandardScaler()
# X = ss.fit_transform(X)

X[:4], y[:4]
# Out:
# (array([[5.1, 3.5, 1.4, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [4.7, 3.2, 1.3, 0.2],
#         [4.6, 3.1, 1.5, 0.2]]),
#  array([-1, -1, -1, -1]))

# %%
# https://github.com/rasbt/python-machine-learning-book-3rd-edition/blob/master/ch02/ch02.py
class AdalineGD(object):
    """ADAptive LInear NEuron classifier.
    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    n_iter : int
      Passes over the training dataset.
    random_state : int
      Random number generator seed for random weight
      initialization.
    Attributes
    -----------
    w_ : 1d-array
      Weights after fitting.
    cost_ : list
      Sum-of-squares cost function value in each epoch.
    """
    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state

    def fit(self, X, y):
        """ Fit training data.
        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.
        Returns
        -------
        self : object
        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.cost_ = []

        for i in range(self.n_iter):
            net_input = self.net_input(X)
            # Please note that the "activation" method has no effect
            # in the code since it is simply an identity function. We
            # could write `output = self.net_input(X)` directly instead.
            # The purpose of the activation is more conceptual, i.e.,  
            # in the case of logistic regression (as we will see later), 
            # we could change it to
            # a sigmoid function to implement a logistic regression classifier.
            output = self.activation(net_input)
            errors = (y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
            # 先列印出每一次成本
            if len(self.cost_) >= 3:
                if np.around(self.cost_[-1],4)==np.around(self.cost_[-2],4) and \
                   np.around(self.cost_[-2],4)==np.around(self.cost_[-3],4) :                
                    print('第 {} 次訓練有 {} 錯誤'.format(i, self.cost_[-1]) )
                    print('訓練中斷因為連續三次已經相同成本到小數點下四位')
                    break
                
            print('第 {} 次訓練有 {} 錯誤'.format(i, self.cost_[-1]) )
        return self

    def net_input(self, X):
        """Calculate net input"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def activation(self, X):
        """Compute linear activation"""
        return X

    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.activation(self.net_input(X)) >= 0.0, 1, -1)

# %%
model = AdalineGD(eta=0.0003, n_iter=5000, random_state=1) # learning rate 攸關是否收斂
model.fit(X, y)
# Out:
# 第 0 次訓練有 51.31813495000615 錯誤
# 第 1 次訓練有 44.79801574009028 錯誤
# 第 2 次訓練有 39.77320799014167 錯誤
# 第 3 次訓練有 35.5078040509796 錯誤
# 第 4 次訓練有 31.768208269531815 錯誤
# 第 5 次訓練有 28.45698223332386 錯誤
# 第 6 次訓練有 25.516385019324208 錯誤
# 第 7 次訓練有 22.90264875039399 錯誤
# 第 8 次訓練有 20.578841296694936 錯誤
# 第 9 次訓練有 18.51264401769571 錯誤
# 第 10 次訓練有 16.675456592118348 錯誤
# 第 11 次訓練有 15.041884308277055 錯誤
# 第 12 次訓練有 13.589356411009426 錯誤
# 第 13 次訓練有 12.297806202649834 錯誤
# 第 14 次訓練有 11.149391698008332 錯誤
# 第 15 次訓練有 10.12824857637995 錯誤
# 第 16 次訓練有 9.220270865003089 錯誤
# 第 17 次訓練有 8.412916021985513 錯誤
# 第 18 次訓練有 7.695031646691534 錯誤
# 第 19 次訓練有 7.056701402788154 錯誤
# 第 20 次訓練有 6.489108019885886 錯誤
# 第 21 次訓練有 5.984411479668887 錯誤
# 第 22 次訓練有 5.535640703239442 錯誤
# 第 23 次訓練有 5.13659724320138 錯誤
# 第 24 次訓練有 4.781769649929076 錯誤
# 第 25 次訓練有 4.466257328955032 錯誤
# 第 26 次訓練有 4.185702837537373 錯誤
# 第 27 次訓練有 3.936231685059908 錯誤
# 第 28 次訓練有 3.7143988055860433 錯誤
# 第 29 次訓練有 3.5171409630659265 錯誤
# 第 30 次訓練有 3.341734431658007 錯誤
# 第 31 次訓練有 3.1857573665037306 錯誤
# 第 32 次訓練有 3.047056345094371 錯誤
# 第 33 次訓練有 2.9237166169871807 錯誤
# 第 34 次訓練有 2.8140356508602142 錯誤
# 第 35 次訓練有 2.7164996134490567 錯誤
# 第 36 次訓練有 2.629762455413693 錯誤
# 第 37 次訓練有 2.55262731519939 錯誤
# 第 38 次訓練有 2.484029983979376 錯誤
# 第 39 次訓練有 2.423024203241687 錯誤
# 第 40 次訓練有 2.368768591901141 錯誤
# 第 41 次訓練有 2.320515022329911 錯誤
# 第 42 次訓練有 2.2775982847174276 錯誤
# 第 43 次訓練有 2.2394268969691584 錯誤
# 第 44 次訓練有 2.205474933179704 錯誤
# 第 45 次訓練有 2.175274757787756 錯誤
# 第 46 次訓練有 2.148410565032659 錯誤
# 第 47 次訓練有 2.1245126344579224 錯誤
# 第 48 次訓練有 2.1032522230994206 錯誤
# 第 49 次訓練有 2.0843370237920715 錯誤
# 第 50 次訓練有 2.0675071268498995 錯誤
# 第 51 次訓練有 2.05253142932866 錯誤
# 第 52 次訓練有 2.0392044422637463 錯誤
# 第 53 次訓練有 2.027343451774209 錯誤
# 第 54 次訓練有 2.016785994812583 錯誤
# 第 55 次訓練有 2.0073876146870813 錯誤
# 第 56 次訓練有 1.9990198653479196 錯誤
# 第 57 次訓練有 1.9915685368662863 錯誤
# 第 58 次訓練有 1.9849320775903159 錯誤
# 第 59 次訓練有 1.9790201911796035 錯誤
# 第 60 次訓練有 1.9737525891357839 錯誤
# 第 61 次訓練有 1.969057881594969 錯誤
# 第 62 次訓練有 1.9648725910579272 錯誤
# 第 63 次訓練有 1.961140275432349 錯誤
# 第 64 次訓練有 1.957810748271726 錯誤
# 第 65 次訓練有 1.9548393854381543 錯誤
# 第 66 次訓練有 1.9521865086103742 錯誤
# 第 67 次訓練有 1.9498168371199929 錯誤
# 第 68 次訓練有 1.947699000542807 錯誤
# 第 69 次訓練有 1.945805105311513 錯誤
# 第 70 次訓練有 1.9441103493624008 錯誤
# 第 71 次訓練有 1.942592679492232 錯誤
# 第 72 次訓練有 1.941232486691587 錯誤
# 第 73 次訓練有 1.940012335245587 錯誤
# 第 74 次訓練有 1.9389167218594185 錯誤
# 第 75 次訓練有 1.9379318614809262 錯誤
# 第 76 次訓練有 1.9370454968612822 錯誤
# 第 77 次訓練有 1.9362467292228136 錯誤
# 第 78 次訓練有 1.9355258676945397 錯誤
# 第 79 次訓練有 1.934874295435364 錯誤
# 第 80 次訓練有 1.9342843505953446 錯誤
# 第 81 次訓練有 1.9337492204704858 錯誤
# 第 82 次訓練有 1.933262847388754 錯誤
# 第 83 次訓練有 1.9328198450271288 錯誤
# 第 84 次訓練有 1.9324154240035363 錯誤
# 第 85 次訓練有 1.9320453257157237 錯誤
# 第 86 次訓練有 1.9317057635130301 錯誤
# 第 87 次訓練有 1.931393370388308 錯誤
# 第 88 次訓練有 1.9311051524673573 錯誤
# 第 89 次訓練有 1.9308384476533 錯誤
# 第 90 次訓練有 1.9305908888545584 錯誤
# 第 91 次訓練有 1.9303603712884227 錯誤
# 第 92 次訓練有 1.930145023408481 錯誤
# 第 93 次訓練有 1.9299431810542806 錯誤
# 第 94 次訓練有 1.9297533644660814 錯誤
# 第 95 次訓練有 1.9295742578471473 錯誤
# 第 96 次訓練有 1.9294046911912328 錯誤
# 第 97 次訓練有 1.929243624124199 錯誤
# 第 98 次訓練有 1.9290901315365159 錯誤
# 第 99 次訓練有 1.9289433908081834 錯誤
# 第 100 次訓練有 1.9288026704495524 錯誤
# 第 101 次訓練有 1.9286673200011335 錯誤
# 第 102 次訓練有 1.9285367610528377 錯誤
# 第 103 次訓練有 1.9284104792586125 錯誤
# 第 104 次訓練有 1.9282880172360943 錯誤
# 第 105 次訓練有 1.9281689682532444 錯誤
# 第 106 次訓練有 1.9280529706147085 錯誤
# 第 107 次訓練有 1.9279397026703564 錯誤
# 第 108 次訓練有 1.9278288783770536 錯誤
# 第 109 次訓練有 1.9277202433523235 錯誤
# 第 110 次訓練有 1.9276135713654075 錯誤
# 第 111 次訓練有 1.9275086612172343 錯誤
# 第 112 次訓練有 1.9274053339661872 錯誤
# 第 113 次訓練有 1.9273034304613557 錯誤
# 第 114 次訓練有 1.9272028091491857 錯誤
# 第 115 次訓練有 1.92710334412322 錯誤
# 第 116 次訓練有 1.9270049233900024 錯誤
# 第 117 次訓練有 1.926907447327171 錯誤
# 第 118 次訓練有 1.9268108273124522 錯誤
# 第 119 次訓練有 1.9267149845046028 錯誤
# 第 120 次訓練有 1.9266198487594666 錯誤
# 第 121 次訓練有 1.9265253576661687 錯誤
# 第 122 次訓練有 1.926431455690136 錯誤
# 第 123 次訓練有 1.9263380934110874 錯誤
# 第 124 次訓練有 1.9262452268454935 錯誤
# 第 125 次訓練有 1.926152816844125 錯誤
# 第 126 次訓練有 1.9260608285563674 錯誤
# 第 127 次訓練有 1.9259692309539185 錯誤
# 第 128 次訓練有 1.925877996407267 錯誤
# 第 129 次訓練有 1.9257871003091118 錯誤
# 第 130 次訓練有 1.925696520739526 錯誤
# 第 131 次訓練有 1.9256062381682229 錯誤
# 第 132 次訓練有 1.925516235189825 錯誤
# 第 133 次訓練有 1.9254264962884766 錯誤
# 第 134 次訓練有 1.9253370076285359 錯誤
# 第 135 次訓練有 1.9252477568684776 錯誤
# 第 136 次訓練有 1.9251587329954074 錯誤
# 第 137 次訓練有 1.9250699261779278 錯誤
# 第 138 次訓練有 1.9249813276353074 錯誤
# 第 139 次訓練有 1.9248929295211512 錯誤
# 第 140 次訓練有 1.9248047248199616 錯誤
# 第 141 次訓練有 1.9247167072551623 錯誤
# 第 142 次訓練有 1.9246288712073227 錯誤
# 第 143 次訓練有 1.9245412116414415 錯誤
# 第 144 次訓練有 1.9244537240422859 錯誤
# 第 145 次訓練有 1.9243664043569015 錯誤
# 第 146 次訓練有 1.9242792489434937 錯誤
# 第 147 次訓練有 1.92419225452597 錯誤
# 第 148 次訓練有 1.9241054181535278 錯誤
# 第 149 次訓練有 1.9240187371647124 錯誤
# 第 150 次訓練有 1.9239322091554636 錯誤
# 第 151 次訓練有 1.923845831950703 錯誤
# 第 152 次訓練有 1.9237596035790694 錯誤
# 第 153 次訓練有 1.9236735222504486 錯誤
# 第 154 次訓練有 1.923587586336006 錯誤
# 第 155 次訓練有 1.9235017943504185 錯誤
# 第 156 次訓練有 1.9234161449360838 錯誤
# 第 157 次訓練有 1.9233306368490768 錯誤
# 第 158 次訓練有 1.923245268946659 錯誤
# 第 159 次訓練有 1.9231600401761821 錯誤
# 第 160 次訓練有 1.9230749495652066 錯誤
# 第 161 次訓練有 1.922989996212725 錯誤
# 第 162 次訓練有 1.9229051792813578 錯誤
# 第 163 次訓練有 1.9228204979904095 錯誤
# 第 164 次訓練有 1.9227359516096942 錯誤
# 第 165 次訓練有 1.9226515394540509 錯誤
# 第 166 次訓練有 1.9225672608784565 錯誤
# 第 167 次訓練有 1.9224831152736928 錯誤
# 第 168 次訓練有 1.9223991020624798 錯誤
# 第 169 次訓練有 1.9223152206960492 錯誤
# 第 170 次訓練有 1.9222314706510868 錯誤
# 第 171 次訓練有 1.9221478514270247 錯誤
# 第 172 次訓練有 1.9220643625436222 錯誤
# 第 173 次訓練有 1.9219810035388205 錯誤
# 第 174 次訓練有 1.9218977739668364 錯誤
# 第 175 次訓練有 1.921814673396462 錯誤
# 第 176 次訓練有 1.9217317014095527 錯誤
# 第 177 次訓練有 1.9216488575996928 錯誤
# 第 178 次訓練有 1.9215661415709897 錯誤
# 第 179 次訓練有 1.9214835529370187 錯誤
# 第 180 次訓練有 1.9214010913198785 錯誤
# 第 181 次訓練有 1.9213187563493486 錯誤
# 第 182 次訓練有 1.9212365476621382 錯誤
# 第 183 次訓練有 1.9211544649012298 錯誤
# 第 184 次訓練有 1.9210725077152773 錯誤
# 第 185 次訓練有 1.9209906757580877 錯誤
# 第 186 次訓練有 1.9209089686881475 錯誤
# 第 187 次訓練有 1.9208273861682106 錯誤
# 第 188 次訓練有 1.9207459278649184 錯誤
# 第 189 次訓練有 1.9206645934484827 錯誤
# 第 190 次訓練有 1.9205833825923802 錯誤
# 第 191 次訓練有 1.9205022949730945 錯誤
# 第 192 次訓練有 1.9204213302698876 錯誤
# 第 193 次訓練有 1.920340488164586 錯誤
# 第 194 次訓練有 1.9202597683413993 錯誤
# 第 195 次訓練有 1.9201791704867561 錯誤
# 第 196 次訓練有 1.9200986942891518 錯誤
# 第 197 次訓練有 1.9200183394390273 錯誤
# 第 198 次訓練有 1.9199381056286444 錯誤
# 第 199 次訓練有 1.9198579925519832 錯誤
# 第 200 次訓練有 1.9197779999046558 錯誤
# 第 201 次訓練有 1.9196981273838118 錯誤
# 第 202 次訓練有 1.9196183746880764 錯誤
# 第 203 次訓練有 1.9195387415174758 錯誤
# 第 204 次訓練有 1.9194592275733826 錯誤
# 第 205 次訓練有 1.9193798325584623 錯誤
# 第 206 次訓練有 1.9193005561766232 錯誤
# 第 207 次訓練有 1.9192213981329782 錯誤
# 第 208 次訓練有 1.9191423581338063 錯誤
# 第 209 次訓練有 1.9190634358865135 錯誤
# 第 210 次訓練有 1.9189846310996086 錯誤
# 第 211 次訓練有 1.9189059434826732 錯誤
# 第 212 次訓練有 1.918827372746337 錯誤
# 第 213 次訓練有 1.9187489186022535 錯誤
# 第 214 次訓練有 1.9186705807630835 錯誤
# 第 215 次訓練有 1.918592358942475 錯誤
# 第 216 次訓練有 1.918514252855048 錯誤
# 第 217 次訓練有 1.9184362622163755 錯誤
# 第 218 次訓練有 1.9183583867429757 錯誤
# 第 219 次訓練有 1.9182806261522964 錯誤
# 第 220 次訓練有 1.9182029801627032 錯誤
# 第 221 次訓練有 1.9181254484934718 錯誤
# 第 222 次訓練有 1.9180480308647745 錯誤
# 第 223 次訓練有 1.9179707269976767 錯誤
# 第 224 次訓練有 1.9178935366141228 錯誤
# 第 225 次訓練有 1.9178164594369354 錯誤
# 第 226 次訓練有 1.9177394951898044 錯誤
# 第 227 次訓練有 1.9176626435972786 錯誤
# 第 228 次訓練有 1.9175859043847638 錯誤
# 第 229 次訓練有 1.9175092772785172 錯誤
# 第 230 次訓練有 1.917432762005639 錯誤
# 第 231 次訓練有 1.9173563582940694 錯誤
# 第 232 次訓練有 1.917280065872582 錯誤
# 第 233 次訓練有 1.9172038844707853 錯誤
# 第 234 次訓練有 1.9171278138191097 錯誤
# 第 235 次訓練有 1.917051853648809 錯誤
# 第 236 次訓練有 1.9169760036919563 錯誤
# 第 237 次訓練有 1.9169002636814387 錯誤
# 第 238 次訓練有 1.916824633350953 錯誤
# 第 239 次訓練有 1.9167491124350065 錯誤
# 第 240 次訓練有 1.9166737006689087 錯誤
# 第 241 次訓練有 1.916598397788768 錯誤
# 第 242 次訓練有 1.9165232035314954 錯誤
# 第 243 次訓練有 1.9164481176347916 錯誤
# 第 244 次訓練有 1.9163731398371526 錯誤
# 第 245 次訓練有 1.916298269877861 錯誤
# 第 246 次訓練有 1.9162235074969862 錯誤
# 第 247 次訓練有 1.91614885243538 錯誤
# 第 248 次訓練有 1.9160743044346746 錯誤
# 第 249 次訓練有 1.915999863237279 錯誤
# 第 250 次訓練有 1.9159255285863772 錯誤
# 第 251 次訓練有 1.9158513002259245 錯誤
# 第 252 次訓練有 1.9157771779006496 錯誤
# 第 253 次訓練有 1.9157031613560402 錯誤
# 第 254 次訓練有 1.9156292503383556 錯誤
# 第 255 次訓練有 1.9155554445946117 錯誤
# 第 256 次訓練有 1.915481743872586 錯誤
# 第 257 次訓練有 1.9154081479208123 錯誤
# 第 258 次訓練有 1.9153346564885783 錯誤
# 第 259 次訓練有 1.9152612693259214 錯誤
# 第 260 次訓練有 1.9151879861836312 錯誤
# 第 261 次訓練有 1.9151148068132409 錯誤
# 第 262 次訓練有 1.9150417309670307 錯誤
# 第 263 次訓練有 1.9149687583980206 錯誤
# 第 264 次訓練有 1.914895888859969 錯誤
# 第 265 次訓練有 1.9148231221073762 錯誤
# 第 266 次訓練有 1.9147504578954715 錯誤
# 第 267 次訓練有 1.9146778959802195 錯誤
# 第 268 次訓練有 1.9146054361183142 錯誤
# 第 269 次訓練有 1.9145330780671774 錯誤
# 第 270 次訓練有 1.914460821584955 錯誤
# 第 271 次訓練有 1.914388666430517 錯誤
# 第 272 次訓練有 1.9143166123634534 錯誤
# 第 273 次訓練有 1.914244659144072 錯誤
# 第 274 次訓練有 1.9141728065333987 錯誤
# 第 275 次訓練有 1.9141010542931707 錯誤
# 第 276 次訓練有 1.9140294021858377 錯誤
# 第 277 次訓練有 1.9139578499745584 錯誤
# 第 278 次訓練有 1.9138863974232 錯誤
# 第 279 次訓練有 1.9138150442963322 錯誤
# 第 280 次訓練有 1.9137437903592267 錯誤
# 第 281 次訓練有 1.9136726353778581 錯誤
# 第 282 次訓練有 1.9136015791188972 錯誤
# 第 283 次訓練有 1.913530621349711 錯誤
# 第 284 次訓練有 1.9134597618383598 錯誤
# 第 285 次訓練有 1.913389000353595 錯誤
# 第 286 次訓練有 1.9133183366648576 錯誤
# 第 287 次訓練有 1.913247770542275 錯誤
# 第 288 次訓練有 1.9131773017566618 錯誤
# 第 289 次訓練有 1.9131069300795114 錯誤
# 第 290 次訓練有 1.9130366552829998 錯誤
# 第 291 次訓練有 1.9129664771399824 錯誤
# 第 292 次訓練有 1.9128963954239873 錯誤
# 第 293 次訓練有 1.9128264099092196 錯誤
# 第 294 次訓練有 1.9127565203705557 錯誤
# 第 295 次訓練有 1.9126867265835414 錯誤
# 第 296 次訓練有 1.9126170283243902 錯誤
# 第 297 次訓練有 1.9125474253699801 錯誤
# 第 298 次訓練有 1.9124779174978537 錯誤
# 第 299 次訓練有 1.9124085044862147 錯誤
# 第 300 次訓練有 1.9123391861139247 錯誤
# 第 301 次訓練有 1.9122699621605048 錯誤
# 第 302 次訓練有 1.9122008324061295 錯誤
# 第 303 次訓練有 1.9121317966316267 錯誤
# 第 304 次訓練有 1.9120628546184746 錯誤
# 第 305 次訓練有 1.9119940061488003 錯誤
# 第 306 次訓練有 1.911925251005378 錯誤
# 第 307 次訓練有 1.9118565889716266 錯誤
# 第 308 次訓練有 1.9117880198316075 錯誤
# 第 309 次訓練有 1.9117195433700247 錯誤
# 第 310 次訓練有 1.9116511593722159 錯誤
# 第 311 次訓練有 1.91158286762416 錯誤
# 第 312 次訓練有 1.911514667912469 錯誤
# 第 313 次訓練有 1.911446560024387 錯誤
# 第 314 次訓練有 1.9113785437477888 錯誤
# 第 315 次訓練有 1.9113106188711781 錯誤
# 第 316 次訓練有 1.9112427851836853 錯誤
# 第 317 次訓練有 1.911175042475063 錯誤
# 第 318 次訓練有 1.9111073905356908 錯誤
# 第 319 次訓練有 1.9110398291565667 錯誤
# 第 320 次訓練有 1.9109723581293057 錯誤
# 第 321 次訓練有 1.910904977246141 錯誤
# 第 322 次訓練有 1.9108376862999215 錯誤
# 第 323 次訓練有 1.9107704850841079 錯誤
# 第 324 次訓練有 1.9107033733927707 錯誤
# 第 325 次訓練有 1.9106363510205924 錯誤
# 第 326 次訓練有 1.9105694177628598 錯誤
# 第 327 次訓練有 1.9105025734154648 錯誤
# 第 328 次訓練有 1.910435817774904 錯誤
# 第 329 次訓練有 1.9103691506382752 錯誤
# 第 330 次訓練有 1.9103025718032718 錯誤
# 第 331 次訓練有 1.910236081068193 錯誤
# 第 332 次訓練有 1.9101696782319237 錯誤
# 第 333 次訓練有 1.9101033630939506 錯誤
# 第 334 次訓練有 1.9100371354543444 錯誤
# 第 335 次訓練有 1.9099709951137749 錯誤
# 第 336 次訓練有 1.9099049418734928 錯誤
# 第 337 次訓練有 1.9098389755353369 錯誤
# 第 338 次訓練有 1.9097730959017312 錯誤
# 第 339 次訓練有 1.9097073027756841 錯誤
# 第 340 次訓練有 1.90964159596078 錯誤
# 第 341 次訓練有 1.9095759752611847 錯誤
# 第 342 次訓練有 1.9095104404816419 錯誤
# 第 343 次訓練有 1.9094449914274685 錯誤
# 第 344 次訓練有 1.909379627904557 錯誤
# 第 345 次訓練有 1.9093143497193699 錯誤
# 第 346 次訓練有 1.9092491566789382 錯誤
# 第 347 次訓練有 1.909184048590865 錯誤
# 第 348 次訓練有 1.9091190252633146 錯誤
# 第 349 次訓練有 1.90905408650502 錯誤
# 第 350 次訓練有 1.9089892321252742 錯誤
# 第 351 次訓練有 1.9089244619339307 錯誤
# 第 352 次訓練有 1.9088597757414034 錯誤
# 第 353 次訓練有 1.9087951733586626 錯誤
# 第 354 次訓練有 1.9087306545972365 錯誤
# 第 355 次訓練有 1.9086662192692032 錯誤
# 第 356 次訓練有 1.9086018671871954 錯誤
# 第 357 次訓練有 1.9085375981643942 錯誤
# 第 358 次訓練有 1.9084734120145315 錯誤
# 第 359 次訓練有 1.9084093085518847 錯誤
# 第 360 次訓練有 1.9083452875912754 錯誤
# 第 361 次訓練有 1.908281348948071 錯誤
# 第 362 次訓練有 1.9082174924381772 錯誤
# 第 363 次訓練有 1.9081537178780437 錯誤
# 第 364 次訓練有 1.9080900250846544 錯誤
# 第 365 次訓練有 1.9080264138755316 錯誤
# 第 366 次訓練有 1.9079628840687324 錯誤
# 第 367 次訓練有 1.9078994354828467 錯誤
# 第 368 次訓練有 1.9078360679369961 錯誤
# 第 369 次訓練有 1.907772781250833 錯誤
# 第 370 次訓練有 1.9077095752445348 錯誤
# 第 371 次訓練有 1.9076464497388086 錯誤
# 第 372 次訓練有 1.9075834045548843 錯誤
# 第 373 次訓練有 1.907520439514515 錯誤
# 第 374 次訓練有 1.907457554439977 錯誤
# 第 375 次訓練有 1.9073947491540644 錯誤
# 第 376 次訓練有 1.907332023480091 錯誤
# 第 377 次訓練有 1.9072693772418847 錯誤
# 第 378 次訓練有 1.9072068102637911 錯誤
# 第 379 次訓練有 1.9071443223706674 錯誤
# 第 380 次訓練有 1.907081913387884 錯誤
# 第 381 次訓練有 1.9070195831413188 錯誤
# 第 382 次訓練有 1.9069573314573618 錯誤
# 第 383 次訓練有 1.9068951581629043 錯誤
# 第 384 次訓練有 1.9068330630853498 錯誤
# 第 385 次訓練有 1.9067710460525995 錯誤
# 第 386 次訓練有 1.906709106893059 錯誤
# 第 387 次訓練有 1.9066472454356358 錯誤
# 第 388 次訓練有 1.906585461509734 錯誤
# 第 389 次訓練有 1.9065237549452552 錯誤
# 第 390 次訓練有 1.9064621255725975 錯誤
# 第 391 次訓練有 1.9064005732226534 錯誤
# 第 392 次訓練有 1.9063390977268089 錯誤
# 第 393 次訓練有 1.9062776989169374 錯誤
# 第 394 次訓練有 1.906216376625406 錯誤
# 第 395 次訓練有 1.9061551306850664 錯誤
# 第 396 次訓練有 1.9060939609292593 錯誤
# 第 397 次訓練有 1.9060328671918096 錯誤
# 第 398 次訓練有 1.9059718493070266 錯誤
# 第 399 次訓練有 1.9059109071096962 錯誤
# 第 400 次訓練有 1.9058500404350918 錯誤
# 第 401 次訓練有 1.905789249118961 錯誤
# 第 402 次訓練有 1.9057285329975306 錯誤
# 第 403 次訓練有 1.9056678919075027 錯誤
# 第 404 次訓練有 1.9056073256860537 錯誤
# 第 405 次訓練有 1.9055468341708326 錯誤
# 第 406 次訓練有 1.9054864171999608 錯誤
# 第 407 次訓練有 1.9054260746120282 錯誤
# 第 408 次訓練有 1.9053658062460923 錯誤
# 第 409 次訓練有 1.9053056119416796 錯誤
# 第 410 次訓練有 1.9052454915387818 錯誤
# 第 411 次訓練有 1.9051854448778527 錯誤
# 第 412 次訓練有 1.9051254717998107 錯誤
# 第 413 次訓練有 1.9050655721460334 錯誤
# 第 414 次訓練有 1.9050057457583593 錯誤
# 第 415 次訓練有 1.9049459924790846 錯誤
# 第 416 次訓練有 1.904886312150962 錯誤
# 第 417 次訓練有 1.9048267046171996 錯誤
# 第 418 次訓練有 1.9047671697214594 錯誤
# 第 419 次訓練有 1.9047077073078555 錯誤
# 第 420 次訓練有 1.9046483172209518 錯誤
# 第 421 次訓練有 1.9045889993057656 錯誤
# 第 422 次訓練有 1.904529753407758 錯誤
# 第 423 次訓練有 1.90447057937284 錯誤
# 第 424 次訓練有 1.9044114770473655 錯誤
# 第 425 次訓練有 1.9043524462781327 錯誤
# 第 426 次訓練有 1.9042934869123835 錯誤
# 第 427 次訓練有 1.9042345987978007 錯誤
# 第 428 次訓練有 1.904175781782507 錯誤
# 第 429 次訓練有 1.9041170357150603 錯誤
# 第 430 次訓練有 1.9040583604444608 錯誤
# 第 431 次訓練有 1.9039997558201405 錯誤
# 第 432 次訓練有 1.9039412216919667 錯誤
# 第 433 次訓練有 1.90388275791024 錯誤
# 第 434 次訓練有 1.9038243643256918 錯誤
# 第 435 次訓練有 1.903766040789483 錯誤
# 第 436 次訓練有 1.9037077871532042 錯誤
# 第 437 次訓練有 1.903649603268874 錯誤
# 第 438 次訓練有 1.9035914889889363 錯誤
# 第 439 次訓練有 1.9035334441662608 錯誤
# 第 440 次訓練有 1.9034754686541382 錯誤
# 第 441 次訓練有 1.9034175623062826 錯誤
# 第 442 次訓練有 1.9033597249768297 錯誤
# 第 443 次訓練有 1.9033019565203355 錯誤
# 第 444 次訓練有 1.9032442567917693 錯誤
# 第 445 次訓練有 1.903186625646523 錯誤
# 第 446 次訓練有 1.9031290629404014 錯誤
# 第 447 次訓練有 1.9030715685296224 錯誤
# 第 448 次訓練有 1.903014142270818 錯誤
# 第 449 次訓練有 1.9029567840210324 錯誤
# 第 450 次訓練有 1.902899493637719 錯誤
# 第 451 次訓練有 1.9028422709787411 錯誤
# 第 452 次訓練有 1.9027851159023688 錯誤
# 第 453 次訓練有 1.9027280282672783 錯誤
# 第 454 次訓練有 1.902671007932553 錯誤
# 第 455 次訓練有 1.9026140547576782 錯誤
# 第 456 次訓練有 1.9025571686025426 錯誤
# 第 457 次訓練有 1.9025003493274366 錯誤
# 第 458 次訓練有 1.9024435967930493 錯誤
# 第 459 次訓練有 1.90238691086047 錯誤
# 第 460 次訓練有 1.9023302913911861 錯誤
# 第 461 次訓練有 1.9022737382470787 錯誤
# 第 462 次訓練有 1.9022172512904276 錯誤
# 第 463 次訓練有 1.902160830383903 錯誤
# 第 464 次訓練有 1.9021044753905705 錯誤
# 第 465 次訓練有 1.9020481861738834 錯誤
# 第 466 次訓練有 1.9019919625976902 錯誤
# 第 467 次訓練有 1.9019358045262253 錯誤
# 第 468 次訓練有 1.901879711824109 錯誤
# 第 469 次訓練有 1.9018236843563536 錯誤
# 第 470 次訓練有 1.9017677219883515 錯誤
# 第 471 次訓練有 1.9017118245858817 錯誤
# 第 472 次訓練有 1.9016559920151042 錯誤
# 第 473 次訓練有 1.901600224142562 錯誤
# 第 474 次訓練有 1.9015445208351793 錯誤
# 第 475 次訓練有 1.9014888819602598 錯誤
# 第 476 次訓練有 1.9014333073854819 錯誤
# 第 477 次訓練有 1.9013777969789036 錯誤
# 第 478 次訓練有 1.9013223506089585 錯誤
# 第 479 次訓練有 1.9012669681444556 錯誤
# 第 480 次訓練有 1.901211649454575 錯誤
# 第 481 次訓練有 1.9011563944088692 錯誤
# 第 482 次訓練有 1.9011012028772631 錯誤
# 第 483 次訓練有 1.9010460747300528 錯誤
# 第 484 次訓練有 1.9009910098378984 錯誤
# 第 485 次訓練有 1.9009360080718314 錯誤
# 第 486 次訓練有 1.9008810693032496 錯誤
# 第 487 次訓練有 1.900826193403915 錯誤
# 第 488 次訓練有 1.900771380245953 錯誤
# 第 489 次訓練有 1.9007166297018512 錯誤
# 第 490 次訓練有 1.9006619416444632 錯誤
# 第 491 次訓練有 1.9006073159470003 錯誤
# 第 492 次訓練有 1.9005527524830321 錯誤
# 第 493 次訓練有 1.9004982511264896 錯誤
# 第 494 次訓練有 1.9004438117516607 錯誤
# 第 495 次訓練有 1.9003894342331857 錯誤
# 第 496 次訓練有 1.9003351184460644 錯誤
# 第 497 次訓練有 1.900280864265649 錯誤
# 第 498 次訓練有 1.900226671567644 錯誤
# 第 499 次訓練有 1.9001725402281056 錯誤
# 第 500 次訓練有 1.900118470123444 錯誤
# 第 501 次訓練有 1.9000644611304127 錯誤
# 第 502 次訓練有 1.9000105131261185 錯誤
# 第 503 次訓練有 1.8999566259880138 錯誤
# 第 504 次訓練有 1.8999027995938982 錯誤
# 第 505 次訓練有 1.899849033821915 錯誤
# 第 506 次訓練有 1.8997953285505529 錯誤
# 第 507 次訓練有 1.8997416836586436 錯誤
# 第 508 次訓練有 1.8996880990253606 錯誤
# 第 509 次訓練有 1.8996345745302157 錯誤
# 第 510 次訓練有 1.8995811100530662 錯誤
# 第 511 次訓練有 1.8995277054741018 錯誤
# 第 512 次訓練有 1.8994743606738556 錯誤
# 第 513 次訓練有 1.8994210755331924 錯誤
# 第 514 次訓練有 1.899367849933316 錯誤
# 第 515 次訓練有 1.8993146837557635 錯誤
# 第 516 次訓練有 1.8992615768824042 錯誤
# 第 517 次訓練有 1.8992085291954435 錯誤
# 第 518 次訓練有 1.8991555405774145 錯誤
# 第 519 次訓練有 1.899102610911182 錯誤
# 第 520 次訓練有 1.8990497400799404 錯誤
# 第 521 次訓練有 1.8989969279672125 錯誤
# 第 522 次訓練有 1.8989441744568472 錯誤
# 第 523 次訓練有 1.898891479433022 錯誤
# 第 524 次訓練有 1.8988388427802372 錯誤
# 第 525 次訓練有 1.8987862643833187 錯誤
# 第 526 次訓練有 1.8987337441274146 錯誤
# 第 527 次訓練有 1.8986812818979968 錯誤
# 第 528 次訓練有 1.8986288775808555 錯誤
# 第 529 次訓練有 1.8985765310621046 錯誤
# 第 530 次訓練有 1.898524242228176 錯誤
# 第 531 次訓練有 1.8984720109658175 錯誤
# 第 532 次訓練有 1.898419837162098 錯誤
# 第 533 次訓練有 1.8983677207043985 錯誤
# 第 534 次訓練有 1.8983156614804184 錯誤
# 第 535 次訓練有 1.8982636593781712 錯誤
# 第 536 次訓練有 1.8982117142859807 錯誤
# 第 537 次訓練有 1.8981598260924861 錯誤
# 第 538 次訓練有 1.8981079946866348 錯誤
# 第 539 次訓練有 1.8980562199576896 錯誤
# 第 540 次訓練有 1.898004501795217 錯誤
# 第 541 次訓練有 1.897952840089095 錯誤
# 第 542 次訓練有 1.897901234729508 錯誤
# 第 543 次訓練有 1.8978496856069489 錯誤
# 第 544 次訓練有 1.8977981926122136 錯誤
# 第 545 次訓練有 1.897746755636402 錯誤
# 第 546 次訓練有 1.8976953745709209 錯誤
# 第 547 次訓練有 1.8976440493074773 錯誤
# 第 548 次訓練有 1.8975927797380812 錯誤
# 第 549 次訓練有 1.8975415657550403 錯誤
# 第 550 次訓練有 1.8974904072509673 錯誤
# 第 551 次訓練有 1.89743930411877 錯誤
# 第 552 次訓練有 1.897388256251654 錯誤
# 第 553 次訓練有 1.8973372635431254 錯誤
# 第 554 次訓練有 1.8972863258869814 錯誤
# 第 555 次訓練有 1.8972354431773202 錯誤
# 第 556 次訓練有 1.8971846153085288 錯誤
# 第 557 次訓練有 1.8971338421752906 錯誤
# 第 558 次訓練有 1.8970831236725814 錯誤
# 第 559 次訓練有 1.8970324596956665 錯誤
# 第 560 次訓練有 1.896981850140105 錯誤
# 第 561 次訓練有 1.8969312949017423 錯誤
# 第 562 次訓練有 1.8968807938767158 錯誤
# 第 563 次訓練有 1.896830346961448 錯誤
# 第 564 次訓練有 1.8967799540526502 錯誤
# 第 565 次訓練有 1.896729615047319 錯誤
# 第 566 次訓練有 1.8966793298427365 錯誤
# 第 567 次訓練有 1.8966290983364695 錯誤
# 第 568 次訓練有 1.8965789204263679 錯誤
# 第 569 次訓練有 1.896528796010563 錯誤
# 第 570 次訓練有 1.89647872498747 錯誤
# 第 571 次訓練有 1.8964287072557837 錯誤
# 第 572 次訓練有 1.8963787427144785 錯誤
# 第 573 次訓練有 1.8963288312628093 錯誤
# 第 574 次訓練有 1.8962789728003078 錯誤
# 第 575 次訓練有 1.896229167226783 錯誤
# 第 576 次訓練有 1.8961794144423207 錯誤
# 第 577 次訓練有 1.8961297143472828 錯誤
# 第 578 次訓練有 1.8960800668423063 錯誤
# 第 579 次訓練有 1.8960304718283003 錯誤
# 第 580 次訓練有 1.8959809292064485 錯誤
# 第 581 次訓練有 1.8959314388782058 錯誤
# 第 582 次訓練有 1.8958820007452992 錯誤
# 第 583 次訓練有 1.8958326147097266 錯誤
# 第 584 次訓練有 1.895783280673754 錯誤
# 第 585 次訓練有 1.8957339985399175 錯誤
# 第 586 次訓練有 1.8956847682110205 錯誤
# 第 587 次訓練有 1.895635589590135 錯誤
# 第 588 次訓練有 1.8955864625805958 錯誤
# 第 589 次訓練有 1.8955373870860077 錯誤
# 第 590 次訓練有 1.895488363010238 錯誤
# 第 591 次訓練有 1.8954393902574171 錯誤
# 第 592 次訓練有 1.8953904687319385 錯誤
# 第 593 次訓練有 1.8953415983384596 錯誤
# 第 594 次訓練有 1.8952927789818985 錯誤
# 第 595 次訓練有 1.8952440105674329 錯誤
# 第 596 次訓練有 1.8951952930005007 錯誤
# 第 597 次訓練有 1.8951466261867997 錯誤
# 第 598 次訓練有 1.8950980100322852 錯誤
# 第 599 次訓練有 1.8950494444431694 錯誤
# 第 600 次訓練有 1.895000929325921 錯誤
# 第 601 次訓練有 1.8949524645872657 錯誤
# 訓練中斷因為連續三次已經相同成本到小數點下三位

# %%
model.w_
# Out:
# array([-0.04360853, -0.09616078, -0.34511089,  0.51171074,  0.23366048])

# %%
model.cost_[-10:] #early stopping, 如果 數值到小數點下三位都一樣的時候 連續三次就停
# Out:
# [2.368768591901141,
#  2.320515022329911,
#  2.2775982847174276,
#  2.2394268969691584,
#  2.205474933179704,
#  2.175274757787756,
#  2.148410565032659,
#  2.1245126344579224,
#  2.1032522230994206,
#  2.0843370237920715]

# %%
import matplotlib.pyplot as plt 
import numpy as np
plt.plot(np.log(model.cost_) , color ='red')
plt.scatter(range(len(model.cost_)), np.log(model.cost_), color ='blue', marker='>')
plt.show()
