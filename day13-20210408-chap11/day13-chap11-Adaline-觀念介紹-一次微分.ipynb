# %%
# y = x**2 + 2*x + 1

import matplotlib.pyplot as plt
import numpy as np
def f(x):
    return( x**2 + 2*x + 1)
def fd(x):
    return( 2 * x  + 2)
    
    
x = np.linspace(-4, 2, 100)
y = f(x)

plt.plot(x, y, color ='red')
plt.plot(x, fd(x), color = 'blue')
plt.show()
