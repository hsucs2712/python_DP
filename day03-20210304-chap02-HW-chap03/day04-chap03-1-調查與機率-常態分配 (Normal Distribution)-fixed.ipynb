# %%
# https://en.wikipedia.org/wiki/Normal_distribution
import numpy as np
import matplotlib.pyplot as plt
def f(x, sigma, mean):
    return(  1/ (sigma * (2*np.pi)**0.5 )  * np.exp(-1/2 * ( (x - mean) / sigma  )**2 ) )

plt.figure(figsize = (12,4))

x = np.linspace(-6, 6, 500)
y = f(x, sigma = 0.2**0.5, mean = 0 )
plt.scatter(x, y, color='blue')

y = f(x, sigma = 1.0**0.5, mean = 0 )
plt.scatter(x, y, color='red')

y = f(x, sigma = 5.0**0.5, mean = 0 )
plt.scatter(x, y, color='yellow')

y = f(x, sigma = 0.5**0.5, mean = -2 )
plt.scatter(x, y, color='green')

plt.grid()
plt.show()

# %%
0.2**0.5, np.sqrt(0.2)
# Out:
# (0.4472135954999579, 0.4472135954999579)

# %%
# https://en.wikipedia.org/wiki/Normal_distribution
import numpy as np
import matplotlib.pyplot as plt
def f(x, sigma, mean):
    #return(  1/ (sigma * (2*np.pi)**0.5 )   *  np.exp( -1/2 * ( (x - mean) / sigma  )**2 ) )
    return(   1/ (sigma * np.sqrt(2 * np.pi)) * np.exp( -1/2 * ( (x - mean) / sigma  )**2 ) )

# def f(x, sigma, mu):
#     return(   1/ (sigma * np.sqrt(2 * np.pi)) * np.exp( -1/2 * (  (x- mu)   /sigma)**2 ) )

plt.figure(figsize = (12,4))

x = np.linspace(-5, 5, 100) ### ????
#x = np.arange(-5, 5, 0.01)    #### ????
y = np.cumsum(f(x, sigma = 0.2**0.5, mean = 0 ))
plt.scatter(x, (y)/y[-1], color='blue')
#print(y)
y = np.cumsum(f(x, sigma = 1.0**0.5, mean = 0 ))
plt.scatter(x, (y)/y[-1], color='red')

y = np.cumsum(f(x, sigma = 5.0**0.5, mean = 0 ))
plt.scatter(x, (y)/y[-1], color='yellow')

y = np.cumsum(f(x, sigma = 0.5**0.5, mean = -2 ))
plt.scatter(x, (y)/y[-1], color='green')

plt.grid()
plt.show()

# %%
#  驗證 linspace, arange

# https://en.wikipedia.org/wiki/Normal_distribution

def f(x, sigma, mean):
    return(   1/ (sigma * np.sqrt(2 * np.pi)) * np.exp( -1/2 * ( (x - mean) / sigma  )**2 ) )

x1 = np.linspace(-5, 5, 100)
x2 = np.arange(-5, 5, 0.1)

y1 = f(x1, sigma = 5.0**0.5, mean = 0 )
y2 = f(x2, sigma = 5.0**0.5, mean = 0 )

np.cumsum(y1)
# Out:
# array([0.01464498, 0.03083003, 0.04868062, 0.06832803, 0.08990903,
#        0.11356559, 0.13944448, 0.16769674, 0.19847718, 0.23194365,
#        0.26825638, 0.30757712, 0.35006824, 0.39589177, 0.44520832,
#        0.49817594, 0.55494898, 0.61567679, 0.68050242, 0.74956133,
#        0.82298   , 0.90087453, 0.98334934, 1.07049572, 1.16239058,
#        1.25909511, 1.3606536 , 1.46709226, 1.5784182 , 1.69461845,
#        1.81565919, 1.94148503, 2.0720185 , 2.20715968, 2.346786  ,
#        2.49075225, 2.63889071, 2.79101156, 2.94690342, 3.10633411,
#        3.26905157, 3.43478503, 3.60324627, 3.77413112, 3.94712109,
#        4.12188511, 4.29808147, 4.47535979, 4.65336309, 4.83173   ,
#        5.01009691, 5.18810021, 5.36537852, 5.54157488, 5.71633891,
#        5.88932887, 6.06021373, 6.22867496, 6.39440842, 6.55712589,
#        6.71655657, 6.87244844, 7.02456929, 7.17270775, 7.31667399,
#        7.45630032, 7.5914415 , 7.72197497, 7.84780081, 7.96884155,
# ...
